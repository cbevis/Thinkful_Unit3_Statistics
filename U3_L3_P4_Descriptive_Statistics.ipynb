# %% [markdown]
# 1. Generate a random variable with 100 datapoints using the code distributionvar = np.random.distributionname([arguments], 100), replacing distributionvar with an appropriate variable name and distributionname with the name of the distribution you’ve chosen, and filling in the empty space in the parentheses with your chosen values for the appropriate parameters. If you feel uncertain about how to do this, go back to the “Other Distributions” assignment for examples of code to use as a starting point.
# 2. Graph the variable using a histogram.
# 3. Compute the mean and standard deviation and plot them as vertical lines on the histogram. (Hint: the “When Does It Break?” assignment you just completed can help you here.)
# 4. Evaluate whether the descriptive statistics provided useful information about the variable. Can you identify any common characteristics of the distributions that could be usefully described using the mean and/or standard deviation, versus the ones that could not?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

size = 100

# %%
def plot_distribution(distribution, name):
    plt.hist(distribution, color='b')
    mean = np.mean(distribution)
    std = np.std(distribution)
    
    plt.axvline(mean, color='c', linewidth=2, linestyle='solid')
    plt.axvline(mean + std, color='c', linewidth=2, linestyle='dashed')
    plt.axvline(mean - std, color='c', linewidth=2, linestyle='dashed')
    
    plt.title(name)
    plt.xlabel('Value')
    plt.ylabel('Counts')
    
    plt.show()
    
    print('The mean is {:0.2f} and the standard deviation is {:0.2f}.'.format(mean, std))

# %% [markdown]
# # 1. Logistic distribution

# %%
# Initialize logistic distribution with loc=0, scale = 1, size = 100
logistic = np.random.logistic(size=size)

plot_distribution(logistic, 'Logistic')
# Out:
# The mean is 0.01 and the standard deviation is 1.81.

# %% [markdown]
# The descriptive statistics are useful.  The mean is fairly well centered and most of the values are in 2 standard deviations.  However, the logistic distribution has heavier tails than the normal distribution.

# %% [markdown]
# # 2. Uniform Distribution

# %%
# Initialize uniform distribution with min 0, max 5
uniform = np.random.uniform(0, 5, size)

plot_distribution(uniform, 'Uniform')
# Out:
# The mean is 2.44 and the standard deviation is 1.47.

# %% [markdown]
# Since any of the values are equally likely with a uniform distribution, the descriptive statistics don't really add much additional information.

# %% [markdown]
# # 3. Power Distribution

# %%
# Initialize power distribution with a = 5
power = np.random.power(5, size)

plot_distribution(power, 'Power')
# Out:
# The mean is 0.85 and the standard deviation is 0.12.

# %% [markdown]
# The mean is useful since it shows the mid-point, but the other descriptive statistics are less informative because this is a skewed distribution.

# %% [markdown]
# # 4. Hypergeometric Distribution

# %%
# INitialize the hypergeometric distribution with ngood = 30, nbad = 60
hypergeometric = np.random.hypergeometric(30, 60, nsample=60, size=size)

plot_distribution(hypergeometric, 'Hypergeometric')
# Out:
# The mean is 20.06 and the standard deviation is 1.95.

# %% [markdown]
# The mean lines up with the peak, but the standard deviations are not centered.  This distribution is skewed.

# %% [markdown]
# # 5. Pareto Distribution

# %%
# Initialize the pareto distribution with a = 5
pareto = np.random.pareto(5, size)

plot_distribution(pareto, 'Pareto II')
# Out:
# The mean is 0.20 and the standard deviation is 0.24.

# %% [markdown]
# This is another skeweed distribution and the descriptive statistics are less informational. In particular mean - standard deviation is to the left of all the data points.

# %% [markdown]
# # 6. Lognormal Distribution

# %%
# Initialize Lognormal Distribution with mean = 0 (of underlying normal distribution)
# and std. = 1 (of underlying normal distribution)
lognormal = np.random.lognormal(mean=0, sigma=1, size=size)

plot_distribution(lognormal, 'Lognormal')
# Out:
# The mean is 1.75 and the standard deviation is 2.29.

# %% [markdown]
# The mean and mode are clearly not the same and this distribution is skewed.

# %% [markdown]
# # Common characteristics of distributions that can be meaningfully described by descriptive statistics

# %% [markdown]
# Distributions that are not skewed and have central tendencies are more meaningfully described by the mean and standard deviations.

# %% [markdown]
# # Additionally
#
# 1. Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and standard deviation of 1.
# 2. Add them together to create a third variable.
# 3. Graph the third variable using a histogram.
# 4. Compute the mean and standard deviation and plot them as vertical lines on the histogram.
# 5. Evaluate the descriptive statistics against the data.

# %%
# Generate two normally distributed variables
rand1 = np.random.normal(5, 0.5, 100)
rand2 = np.random.normal(10, 1, 100)

rand3 = rand1 + rand2

plot_distribution(rand3, 'Two Normal Distributions Added Together')
# Out:
# The mean is 15.08 and the standard deviation is 1.17.

# %% [markdown]
# The distribution is a little skewed, but if you add more data points, it appears to become less skewed. According to wikipedia, the sum of two normally distributed random variables is also normally distributed.

# %%
# Generate two normally distributed variables
rand1 = np.random.normal(5, 0.5, 100000)
rand2 = np.random.normal(10, 1, 100000)

rand3 = rand1 + rand2

plot_distribution(rand3, 'Two Normal Distributions Added Together')
# Out:
# The mean is 15.00 and the standard deviation is 1.12.
